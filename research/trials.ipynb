# %%
d={"key":"value","key1":"val1"}

# %%
# %pip install python-box
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------------------------- ---- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox

# %%
pip install gdown
# Out:
# ...
#   Using cached beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# ...
# Using cached tqdm-4.70.0-py3-none-any.whl (80 kB)
# Using cached certifi-2026.7.22-py3-none-any.whl (136 kB)
# ...
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# %%
https://drive.google.com/file/d/1TK6UY7yeeizcj05bRniojA9G1dRiUWp2/view?usp=sharing

# %%
url="https://drive.google.com/file/d/1TK6UY7yeeizcj05bRniojA9G1dRiUWp2/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1TK6UY7yeeizcj05bRniojA9G1dRiUWp2'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1TK6UY7yeeizcj05bRniojA9G1dRiUWp2
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1TK6UY7yeeizcj05bRniojA9G1dRiUWp2&confirm=t&uuid=1c8985b2-d779-4a13-ac58-de092a326688
# To: e:\Kidney Disease\research\kidney-CT-Scan-data.zip
#  15%|█▍        | 236M/1.63G [00:21<03:00, 7.71MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 prefix = 'https://drive.google.com/uc?/export=download&id='
# ----> 2 gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
#
# File e:\conda\envs\kidney1\lib\site-packages\gdown\download.py:375, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     373 t_start = time.time()
#     374 downloaded = 0
# ...
